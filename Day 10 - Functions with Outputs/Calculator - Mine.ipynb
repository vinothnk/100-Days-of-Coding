# %%
#1st step
# create functions for the different operations
#store the results into global result variable

from art import logo
print(logo)

#operator functions

def add(n1, n2):
    return n1 + n2

def subtract(n1, n2):
    return n1 - n2

def multiply(n1, n2):
    return n1 * n2

def divide(n1, n2):
    return n1 / n2

def working(n1, n2):
    global result
    if operation == "+":
        result = add(n1, n2)
    elif operation == "-":
        result = subtract(n1, n2)
    elif operation == "*":
        result = multiply(n1, n2)
    else:
        operation == "/"
        result = divide(n1, n2)    
    
        

operations_dict = {"+": "+", "-":"-", "*":"*", "/":"/"}

def start():
    global operation
    for char in operations_dict:
        print(operations_dict[char])
    operation = input("Pick an operation: ")
    n2 = float(input("Enter 2nd number: "))
    working(n1, n2)
    print(result)
    global question
    question = input(f"Type 'y' to continue calculating with {result}, or 'n' to start a new calculation:")

    

function = True

n1 = float(input("Enter 1st number: "))
start()
while function is True:
    if question == 'y':
        n1 = result
        start()
    else:
        function = False
        print("Thank you for using the calculator.")
# Out:
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# ...

# %%
import random
from art import logo
from art import vs
print (logo)

from game_data import data

#generate 1st details
def generate_A():
    global num_A
    global name_A
    global description_A
    global country_A
    global follower_count_A
    num_A = random.randint(0,49)
    name_A = data[num_A]['name']
    description_A = data[num_A]['description']
    country_A = data[num_A]['country']
    follower_count_A = data[num_A]['follower_count']
    print(name_A)
    print(f"follower count is {follower_count_A}")
    return

#generate 2nd details
def generate_B():
    global num_B
    global name_B
    global description_B
    global country_B
    global follower_count_B
    num_B = random.randint(0,49)
    name_B = data[num_B]['name']
    description_B = data[num_B]['description']
    country_B = data[num_B]['country']
    follower_count_B = data[num_B]['follower_count']
    print(name_B)
    print(f"follower count is {follower_count_B}")
    return

def change_BtoA():
    global new_name_A
    global new_description_A
    global new_country_A
    global new_follower_count_A
    new_name_A = name_B
    new_description_A = description_B
    new_country_A = country_B
    new_follower_count_A = follower_count_B
    print(new_name_A)
    print(f"follower count is {new_follower_count_A}")
    return print(new_name_A, new_description_A, new_country_A, new_follower_count_A)

def first_print():
    print(f"Compare A: {name_A}, {description_A}, {country_A}")
    print(vs)
    print(f"Compare B: {name_B}, {description_B}, {country_B}")
    return

def second_print():
    print(f"Compare A: {new_name_A}, {new_description_A}, {new_country_A}")
    print(vs)
    print(f"Compare B: {name_B}, {description_B}, {country_B}")
    return

def ask_question():
    question = input("Which category has more followers? A/B?: ")
    question = question.upper()
    return

def check_if_same(num_A, num_B):
    if num_A == num_B:
        generate_A()
        generate_B()
    return

generate_A()
generate_B()
check_if_same(num_A, num_B)

first_print()

game_start = True
game_score = 0


while game_start is True:
    question = input("Which category has more followers? A/B?: ")
    question = question.upper()

    if question == "A":
        if follower_count_A < follower_count_B:
            print(f"Your score is {game_score}.")
            print("Game Over.")
            game_start = False
        else:
            game_score += 1
            print(f"Your score is {game_score}.")
            change_BtoA()
            generate_B()
            second_print()
            game_start = True
    else:
        question == "B"
        if follower_count_A > follower_count_B:
            print(f"Your score is {game_score}.")
            print("Game Over.")
            game_start = False
        else:
            game_score += 1
            print(f"Your score is {game_score}.")
            change_BtoA()
            generate_B()
            second_print()
            game_start = True
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Selena Gomez
# follower count is 174
# Ellen DeGeneres
# follower count is 87
# Compare A: Selena Gomez, Musician and actress, United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Ellen DeGeneres, Comedian, United States
# Which category has more followers? A/B?: a
# Your score is 1.
# Ellen DeGeneres
# follower count is 87
# Ellen DeGeneres Comedian United States 87
# Gigi Hadid
# follower count is 54
# Compare A: Ellen DeGeneres, Comedian, United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Gigi Hadid, Model, United States
# Which category has more followers? A/B?: a
# Your score is 2.
# Gigi Hadid
# follower count is 54
# Gigi Hadid Model United States 54
# Shakira
# follower count is 66
# Compare A: Gigi Hadid, Model, United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Shakira, Musician, Colombia
# Which category has more followers? A/B?: b
# Your score is 2.
# Game Over.

# %%
import random
from art import logo
from art import vs
print (logo)

from game_data import data

#generate 1st details
def generate_A():
    global num_A
    global name_A
    global description_A
    global country_A
    global follower_count_A
    num_A = random.randint(0,49)
    name_A = data[num_A]['name']
    description_A = data[num_A]['description']
    country_A = data[num_A]['country']
    follower_count_A = data[num_A]['follower_count']
    print(name_A)
    print(f"follower count is {follower_count_A}")
    return

#generate 2nd details
def generate_B():
    global num_B
    global name_B
    global description_B
    global country_B
    global follower_count_B
    num_B = random.randint(0,49)
    name_B = data[num_B]['name']
    description_B = data[num_B]['description']
    country_B = data[num_B]['country']
    follower_count_B = data[num_B]['follower_count']
    print(name_B)
    print(f"follower count is {follower_count_B}")
    return

def change_BtoA():
    global new_name_A
    global new_description_A
    global new_country_A
    global new_follower_count_A
    new_name_A = name_B
    new_description_A = description_B
    new_country_A = country_B
    new_follower_count_A = follower_count_B
    print(new_name_A)
    print(f"follower count is {new_follower_count_A}")
    return print(new_name_A, new_description_A, new_country_A, new_follower_count_A)

def first_print():
    print(f"Compare A: {name_A}, {description_A}, {country_A}")
    print(vs)
    print(f"Compare B: {name_B}, {description_B}, {country_B}")
    return

def second_print():
    print(f"Compare A: {new_name_A}, {new_description_A}, {new_country_A}")
    print(vs)
    print(f"Compare B: {name_B}, {description_B}, {country_B}")
    return

def ask_question():
    question = input("Which category has more followers? A/B?: ")
    question = question.upper()
    return

def check_if_same(num_A, num_B):
    if num_A == num_B:
        generate_A()
        generate_B()
    return

generate_A()
generate_B()
check_if_same(num_A, num_B)

first_print()

game_start = True
game_score = 0


while game_start is True:
    question = input("Which category has more followers? A/B?: ")
    question = question.upper()

    if follower_count_A > follower_count_B:
        if question == "B":
            print(f"Your score is {game_score}.")
            print("Game Over.")
            game_start = False
        elif question == "A":
            game_score += 1
            print(f"Your score is {game_score}.")
            change_BtoA()
            generate_B()
            second_print()
            game_start = True
    elif follower_count_A < follower_count_B:
        if question == "A":
            print(f"Your score is {game_score}.")
            print("Game Over.")
            game_start = False
        elif question == "B":
            game_score += 1
            print(f"Your score is {game_score}.")
            change_BtoA()
            generate_B()
            second_print()
            game_start = True
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Victoria's Secret
# follower count is 69
# 9GAG
# follower count is 52
# Compare A: Victoria's Secret, Lingerie brand, United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: 9GAG, Social media platform, China
# Which category has more followers? A/B?: a
# Your score is 1.
# 9GAG
# follower count is 52
# 9GAG Social media platform China 52
# Lionel Messi
# follower count is 149
# Compare A: 9GAG, Social media platform, China
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: Lionel Messi, Footballer, Argentina
# Which category has more followers? A/B?: b
# Your score is 2.
# Lionel Messi
# follower count is 149
# Lionel Messi Footballer Argentina 149
# David Beckham
# follower count is 82
# Compare A: Lionel Messi, Footballer, Argentina
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Compare B: David Beckham, Footballer, United Kingdom
# Which category has more followers? A/B?: a
# Your score is 2.
# Game Over.
